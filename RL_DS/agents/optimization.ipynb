# %%
# prompt: mount drive and become a path as the working drectory and add to path system

from google.colab import drive
import sys
import os
drive.mount('/content/drive')

path="/content/drive/My Drive/cod/RL_DS_dynamic"
os.chdir(path)
sys.path.append(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from RL_DS.envs.ModeloTesisIvan import RetailerOrders

# %%
time=36
env=RetailerOrders()

# %%
actions=[50]*time

# %%
env.run(actions)
# Out:
# 48563.87978386929

# %%
env.retailer_total_cost
# Out:
# 2915.228685451601

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Using cached scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-25.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (24.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 3.1 MB/s eta 0:00:00
# Downloading pyaml-25.1.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-25.1.0 scikit-optimize-0.10.2

# %%
#Differential Evolution
from scipy.optimize import differential_evolution

bounds = [(0, 500)] * time

def objective_de(actions):
  env=RetailerOrders()
  env.run(actions)
  return env.retailer_total_cost

result_de = differential_evolution(objective_de, bounds, seed=0, disp=True,maxiter=1000)

print("Best parameters found by Differential Evolution:")
print(result_de.x)
print("Best cost found by Differential Evolution:")
print(-result_de.fun)
# Out:
# differential_evolution step 1: f(x)= 3053.2545622194775
# differential_evolution step 2: f(x)= 2514.6055190616403
# differential_evolution step 3: f(x)= 2180.9387156176335
# differential_evolution step 4: f(x)= 2046.48858770378
# differential_evolution step 5: f(x)= 1561.4990641595464
# differential_evolution step 6: f(x)= 1561.4990641595464
# differential_evolution step 7: f(x)= 1561.4990641595464
# differential_evolution step 8: f(x)= 1331.85040749079
# differential_evolution step 9: f(x)= 1331.85040749079
# differential_evolution step 10: f(x)= 1331.85040749079
# differential_evolution step 11: f(x)= 1241.6013595830743
# differential_evolution step 12: f(x)= 1212.8326813917824
# differential_evolution step 13: f(x)= 1212.8326813917824
# differential_evolution step 14: f(x)= 1212.8326813917824
# differential_evolution step 15: f(x)= 1212.8326813917824
# differential_evolution step 16: f(x)= 1085.5988608304679
# differential_evolution step 17: f(x)= 1085.5988608304679
# differential_evolution step 18: f(x)= 1085.5988608304679
# differential_evolution step 19: f(x)= 1049.4182567732712
# differential_evolution step 20: f(x)= 1049.4182567732712
# differential_evolution step 21: f(x)= 1049.4182567732712
# differential_evolution step 22: f(x)= 1049.4182567732712
# differential_evolution step 23: f(x)= 1049.4182567732712
# differential_evolution step 24: f(x)= 1049.4182567732712
# differential_evolution step 25: f(x)= 878.8296186816042
# differential_evolution step 26: f(x)= 878.8296186816042
# differential_evolution step 27: f(x)= 878.8296186816042
# differential_evolution step 28: f(x)= 878.8296186816042
# differential_evolution step 29: f(x)= 878.8296186816042
# differential_evolution step 30: f(x)= 878.8296186816042
# differential_evolution step 31: f(x)= 878.8296186816042
# differential_evolution step 32: f(x)= 878.8296186816042
# differential_evolution step 33: f(x)= 862.9565982301034
# differential_evolution step 34: f(x)= 862.9565982301034
# differential_evolution step 35: f(x)= 826.8888135960804
# differential_evolution step 36: f(x)= 826.8888135960804
# differential_evolution step 37: f(x)= 826.8888135960804
# differential_evolution step 38: f(x)= 797.2844185624851
# differential_evolution step 39: f(x)= 797.2844185624851
# differential_evolution step 40: f(x)= 776.6952003887042
# differential_evolution step 41: f(x)= 776.6952003887042
# differential_evolution step 42: f(x)= 713.8046153948769
# differential_evolution step 43: f(x)= 713.8046153948769
# differential_evolution step 44: f(x)= 713.8046153948769
# differential_evolution step 45: f(x)= 713.8046153948769
# differential_evolution step 46: f(x)= 713.8046153948769
# differential_evolution step 47: f(x)= 713.8046153948769
# differential_evolution step 48: f(x)= 713.8046153948769
# differential_evolution step 49: f(x)= 713.8046153948769
# differential_evolution step 50: f(x)= 713.8046153948769
# differential_evolution step 51: f(x)= 713.8046153948769
# differential_evolution step 52: f(x)= 713.8046153948769
# differential_evolution step 53: f(x)= 713.8046153948769
# differential_evolution step 54: f(x)= 713.8046153948769
# differential_evolution step 55: f(x)= 713.8046153948769
# differential_evolution step 56: f(x)= 700.5723637383159
# differential_evolution step 57: f(x)= 700.5723637383159
# differential_evolution step 58: f(x)= 700.5723637383159
# differential_evolution step 59: f(x)= 693.9384548176264
# differential_evolution step 60: f(x)= 693.9384548176264
# differential_evolution step 61: f(x)= 693.9384548176264
# differential_evolution step 62: f(x)= 693.9384548176264
# differential_evolution step 63: f(x)= 693.9384548176264
# differential_evolution step 64: f(x)= 682.1669206645861
# differential_evolution step 65: f(x)= 682.1669206645861
# differential_evolution step 66: f(x)= 682.1669206645861
# differential_evolution step 67: f(x)= 657.1338789854892
# differential_evolution step 68: f(x)= 657.1338789854892
# differential_evolution step 69: f(x)= 657.1338789854892
# differential_evolution step 70: f(x)= 598.9833301323582
# differential_evolution step 71: f(x)= 598.9833301323582
# differential_evolution step 72: f(x)= 598.9833301323582
# differential_evolution step 73: f(x)= 598.9833301323582
# differential_evolution step 74: f(x)= 598.9833301323582
# differential_evolution step 75: f(x)= 598.9833301323582
# differential_evolution step 76: f(x)= 598.9833301323582
# differential_evolution step 77: f(x)= 598.5503800444785
# differential_evolution step 78: f(x)= 598.5503800444785
# differential_evolution step 79: f(x)= 598.5503800444785
# differential_evolution step 80: f(x)= 598.5503800444785
# differential_evolution step 81: f(x)= 598.5503800444785
# differential_evolution step 82: f(x)= 598.5503800444785
# differential_evolution step 83: f(x)= 598.5503800444785
# differential_evolution step 84: f(x)= 598.5503800444785
# differential_evolution step 85: f(x)= 585.8325856889246
# differential_evolution step 86: f(x)= 585.8325856889246
# differential_evolution step 87: f(x)= 585.8325856889246
# differential_evolution step 88: f(x)= 585.8325856889246
# differential_evolution step 89: f(x)= 585.3565558126546
# differential_evolution step 90: f(x)= 585.3565558126546
# differential_evolution step 91: f(x)= 585.3565558126546
# differential_evolution step 92: f(x)= 585.3565558126546
# differential_evolution step 93: f(x)= 585.3565558126546
# differential_evolution step 94: f(x)= 585.3565558126546
# differential_evolution step 95: f(x)= 585.3565558126546
# differential_evolution step 96: f(x)= 585.3565558126546
# differential_evolution step 97: f(x)= 584.8123684991923
# differential_evolution step 98: f(x)= 584.8123684991923
# differential_evolution step 99: f(x)= 584.8123684991923
# differential_evolution step 100: f(x)= 584.8123684991923
# differential_evolution step 101: f(x)= 584.8123684991923
# differential_evolution step 102: f(x)= 584.8123684991923
# differential_evolution step 103: f(x)= 584.8123684991923
# differential_evolution step 104: f(x)= 579.0107376697207
# differential_evolution step 105: f(x)= 579.0107376697207
# differential_evolution step 106: f(x)= 579.0107376697207
# differential_evolution step 107: f(x)= 579.0107376697207
# differential_evolution step 108: f(x)= 579.0107376697207
# differential_evolution step 109: f(x)= 579.0107376697207
# differential_evolution step 110: f(x)= 579.0107376697207
# differential_evolution step 111: f(x)= 579.0107376697207
# differential_evolution step 112: f(x)= 579.0107376697207
# differential_evolution step 113: f(x)= 579.0107376697207
# differential_evolution step 114: f(x)= 578.9807729372703
# differential_evolution step 115: f(x)= 578.9807729372703
# differential_evolution step 116: f(x)= 578.9807729372703
# differential_evolution step 117: f(x)= 578.9807729372703
# differential_evolution step 118: f(x)= 578.4932316917659
# differential_evolution step 119: f(x)= 578.4932316917659
# differential_evolution step 120: f(x)= 578.4932316917659
# differential_evolution step 121: f(x)= 568.2591355126709
# differential_evolution step 122: f(x)= 568.2591355126709
# differential_evolution step 123: f(x)= 568.2591355126709
# differential_evolution step 124: f(x)= 568.2591355126709
# differential_evolution step 125: f(x)= 568.2591355126709
# differential_evolution step 126: f(x)= 568.2591355126709
# differential_evolution step 127: f(x)= 568.2591355126709
# differential_evolution step 128: f(x)= 568.2591355126709
# differential_evolution step 129: f(x)= 568.2591355126709
# differential_evolution step 130: f(x)= 568.2591355126709
# differential_evolution step 131: f(x)= 568.2591355126709
# differential_evolution step 132: f(x)= 551.8500285230647
# differential_evolution step 133: f(x)= 551.8500285230647
# differential_evolution step 134: f(x)= 551.8500285230647
# differential_evolution step 135: f(x)= 551.8500285230647
# differential_evolution step 136: f(x)= 551.8500285230647
# differential_evolution step 137: f(x)= 551.742210395301
# differential_evolution step 138: f(x)= 551.742210395301
# differential_evolution step 139: f(x)= 551.742210395301
# differential_evolution step 140: f(x)= 551.742210395301
# differential_evolution step 141: f(x)= 551.742210395301
# differential_evolution step 142: f(x)= 551.742210395301
# differential_evolution step 143: f(x)= 551.742210395301
# differential_evolution step 144: f(x)= 551.742210395301
# differential_evolution step 145: f(x)= 551.742210395301
# differential_evolution step 146: f(x)= 551.742210395301
# differential_evolution step 147: f(x)= 551.742210395301
# differential_evolution step 148: f(x)= 551.742210395301
# differential_evolution step 149: f(x)= 551.0435397786947
# differential_evolution step 150: f(x)= 551.0435397786947
# differential_evolution step 151: f(x)= 551.0435397786947
# differential_evolution step 152: f(x)= 551.0435397786947
# differential_evolution step 153: f(x)= 535.0232327403593
# differential_evolution step 154: f(x)= 535.0232327403593
# differential_evolution step 155: f(x)= 535.0232327403593
# differential_evolution step 156: f(x)= 535.0232327403593
# differential_evolution step 157: f(x)= 535.0232327403593
# differential_evolution step 158: f(x)= 535.0232327403593
# differential_evolution step 159: f(x)= 535.0232327403593
# differential_evolution step 160: f(x)= 535.0232327403593
# differential_evolution step 161: f(x)= 535.0232327403593
# differential_evolution step 162: f(x)= 535.0232327403593
# differential_evolution step 163: f(x)= 535.0232327403593
# differential_evolution step 164: f(x)= 535.0232327403593
# differential_evolution step 165: f(x)= 535.0232327403593
# differential_evolution step 166: f(x)= 535.0232327403593
# differential_evolution step 167: f(x)= 535.0232327403593
# differential_evolution step 168: f(x)= 535.0232327403593
# differential_evolution step 169: f(x)= 535.0232327403593
# differential_evolution step 170: f(x)= 535.0232327403593
# differential_evolution step 171: f(x)= 535.0232327403593
# differential_evolution step 172: f(x)= 535.0232327403593
# differential_evolution step 173: f(x)= 535.0232327403593
# differential_evolution step 174: f(x)= 535.0232327403593
# differential_evolution step 175: f(x)= 535.0232327403593
# differential_evolution step 176: f(x)= 535.0232327403593
# differential_evolution step 177: f(x)= 535.0232327403593
# differential_evolution step 178: f(x)= 535.0232327403593
# differential_evolution step 179: f(x)= 535.0232327403593
# differential_evolution step 180: f(x)= 535.0232327403593
# differential_evolution step 181: f(x)= 527.8719797691642
# differential_evolution step 182: f(x)= 527.8719797691642
# differential_evolution step 183: f(x)= 527.8719797691642
# differential_evolution step 184: f(x)= 527.8719797691642
# differential_evolution step 185: f(x)= 527.8719797691642
# differential_evolution step 186: f(x)= 527.8719797691642
# differential_evolution step 187: f(x)= 527.8719797691642
# differential_evolution step 188: f(x)= 527.8719797691642
# differential_evolution step 189: f(x)= 527.8719797691642
# differential_evolution step 190: f(x)= 527.8719797691642
# differential_evolution step 191: f(x)= 527.8719797691642
# differential_evolution step 192: f(x)= 527.8719797691642
# differential_evolution step 193: f(x)= 527.8719797691642
# differential_evolution step 194: f(x)= 527.8719797691642
# differential_evolution step 195: f(x)= 527.8719797691642
# differential_evolution step 196: f(x)= 527.8719797691642
# differential_evolution step 197: f(x)= 527.8719797691642
# differential_evolution step 198: f(x)= 527.8719797691642
# differential_evolution step 199: f(x)= 527.8719797691642
# differential_evolution step 200: f(x)= 527.8719797691642
# differential_evolution step 201: f(x)= 527.8719797691642
# differential_evolution step 202: f(x)= 527.8719797691642
# differential_evolution step 203: f(x)= 527.6124329411616
# differential_evolution step 204: f(x)= 527.6124329411616
# differential_evolution step 205: f(x)= 527.6124329411616
# differential_evolution step 206: f(x)= 520.3044838592572
# differential_evolution step 207: f(x)= 520.3044838592572
# differential_evolution step 208: f(x)= 520.3044838592572
# differential_evolution step 209: f(x)= 520.3044838592572
# differential_evolution step 210: f(x)= 520.3044838592572
# differential_evolution step 211: f(x)= 520.3044838592572
# differential_evolution step 212: f(x)= 520.3044838592572
# differential_evolution step 213: f(x)= 520.3044838592572
# differential_evolution step 214: f(x)= 520.3044838592572
# differential_evolution step 215: f(x)= 518.3373910530067
# differential_evolution step 216: f(x)= 518.3373910530067
# differential_evolution step 217: f(x)= 518.3373910530067
# differential_evolution step 218: f(x)= 518.3373910530067
# differential_evolution step 219: f(x)= 518.3373910530067
# differential_evolution step 220: f(x)= 518.3373910530067
# differential_evolution step 221: f(x)= 518.3373910530067
# differential_evolution step 222: f(x)= 518.3373910530067
# differential_evolution step 223: f(x)= 518.3373910530067
# differential_evolution step 224: f(x)= 518.3373910530067
# differential_evolution step 225: f(x)= 518.3373910530067
# differential_evolution step 226: f(x)= 518.3373910530067
# differential_evolution step 227: f(x)= 515.3579897537002
# differential_evolution step 228: f(x)= 515.3579897537002
# differential_evolution step 229: f(x)= 515.3579897537002
# differential_evolution step 230: f(x)= 515.3579897537002
# differential_evolution step 231: f(x)= 515.3579897537002
# differential_evolution step 232: f(x)= 515.3579897537002
# differential_evolution step 233: f(x)= 515.3579897537002
# differential_evolution step 234: f(x)= 515.3579897537002
# differential_evolution step 235: f(x)= 515.3579897537002
# differential_evolution step 236: f(x)= 515.3579897537002
# differential_evolution step 237: f(x)= 515.3579897537002
# differential_evolution step 238: f(x)= 515.3579897537002
# differential_evolution step 239: f(x)= 515.3579897537002
# differential_evolution step 240: f(x)= 515.3579897537002
# differential_evolution step 241: f(x)= 511.8371617408457
# differential_evolution step 242: f(x)= 511.8371617408457
# differential_evolution step 243: f(x)= 511.8371617408457
# differential_evolution step 244: f(x)= 511.8371617408457
# differential_evolution step 245: f(x)= 511.8371617408457
# differential_evolution step 246: f(x)= 511.8371617408457
# differential_evolution step 247: f(x)= 511.8371617408457
# differential_evolution step 248: f(x)= 511.8371617408457
# differential_evolution step 249: f(x)= 511.8371617408457
# differential_evolution step 250: f(x)= 511.27491785761885
# differential_evolution step 251: f(x)= 511.27491785761885
# differential_evolution step 252: f(x)= 511.27491785761885
# differential_evolution step 253: f(x)= 511.27491785761885
# differential_evolution step 254: f(x)= 511.27491785761885
# differential_evolution step 255: f(x)= 511.27491785761885
# differential_evolution step 256: f(x)= 511.27491785761885
# differential_evolution step 257: f(x)= 511.27491785761885
# differential_evolution step 258: f(x)= 511.27491785761885
# differential_evolution step 259: f(x)= 511.27491785761885
# differential_evolution step 260: f(x)= 503.1652289850853
# differential_evolution step 261: f(x)= 503.1652289850853
# differential_evolution step 262: f(x)= 503.1652289850853
# differential_evolution step 263: f(x)= 503.1652289850853
# differential_evolution step 264: f(x)= 503.1652289850853
# differential_evolution step 265: f(x)= 503.1652289850853
# differential_evolution step 266: f(x)= 503.1652289850853
# differential_evolution step 267: f(x)= 503.1652289850853
# differential_evolution step 268: f(x)= 503.1652289850853
# differential_evolution step 269: f(x)= 503.1652289850853
# differential_evolution step 270: f(x)= 503.1652289850853
# differential_evolution step 271: f(x)= 503.1652289850853
# differential_evolution step 272: f(x)= 503.1652289850853
# differential_evolution step 273: f(x)= 503.1652289850853
# differential_evolution step 274: f(x)= 503.1652289850853
# differential_evolution step 275: f(x)= 503.1652289850853
# differential_evolution step 276: f(x)= 503.1652289850853
# differential_evolution step 277: f(x)= 503.1652289850853
# differential_evolution step 278: f(x)= 503.1652289850853
# differential_evolution step 279: f(x)= 503.1652289850853
# differential_evolution step 280: f(x)= 503.1652289850853
# differential_evolution step 281: f(x)= 502.3126714531181
# differential_evolution step 282: f(x)= 502.3126714531181
# differential_evolution step 283: f(x)= 502.3126714531181
# differential_evolution step 284: f(x)= 502.3126714531181
# differential_evolution step 285: f(x)= 502.3126714531181
# differential_evolution step 286: f(x)= 502.3126714531181
# differential_evolution step 287: f(x)= 502.3126714531181
# differential_evolution step 288: f(x)= 502.3126714531181
# differential_evolution step 289: f(x)= 502.3126714531181
# differential_evolution step 290: f(x)= 502.3126714531181
# differential_evolution step 291: f(x)= 502.3126714531181
# differential_evolution step 292: f(x)= 502.3126714531181
# differential_evolution step 293: f(x)= 502.3126714531181
# differential_evolution step 294: f(x)= 502.3126714531181
# differential_evolution step 295: f(x)= 502.3126714531181
# differential_evolution step 296: f(x)= 502.3126714531181
# differential_evolution step 297: f(x)= 502.3126714531181
# differential_evolution step 298: f(x)= 502.3126714531181
# differential_evolution step 299: f(x)= 502.3126714531181
# differential_evolution step 300: f(x)= 502.3126714531181
# differential_evolution step 301: f(x)= 502.3126714531181
# differential_evolution step 302: f(x)= 500.6199123396672
# differential_evolution step 303: f(x)= 500.6199123396672
# differential_evolution step 304: f(x)= 500.6199123396672
# differential_evolution step 305: f(x)= 500.6199123396672
# differential_evolution step 306: f(x)= 500.6199123396672
# differential_evolution step 307: f(x)= 500.6199123396672
# differential_evolution step 308: f(x)= 500.6199123396672
# differential_evolution step 309: f(x)= 500.6199123396672
# differential_evolution step 310: f(x)= 500.6199123396672
# differential_evolution step 311: f(x)= 500.6199123396672
# differential_evolution step 312: f(x)= 500.6199123396672
# differential_evolution step 313: f(x)= 500.6199123396672
# differential_evolution step 314: f(x)= 500.6199123396672
# differential_evolution step 315: f(x)= 500.6199123396672
# differential_evolution step 316: f(x)= 500.6199123396672
# differential_evolution step 317: f(x)= 500.6199123396672
# differential_evolution step 318: f(x)= 499.6222555909282
# differential_evolution step 319: f(x)= 499.6222555909282
# differential_evolution step 320: f(x)= 499.6222555909282
# differential_evolution step 321: f(x)= 499.6222555909282
# differential_evolution step 322: f(x)= 499.6222555909282
# differential_evolution step 323: f(x)= 499.6222555909282
# differential_evolution step 324: f(x)= 499.6222555909282
# differential_evolution step 325: f(x)= 499.2760340139797
# differential_evolution step 326: f(x)= 499.2760340139797
# differential_evolution step 327: f(x)= 499.2760340139797
# differential_evolution step 328: f(x)= 499.2760340139797
# differential_evolution step 329: f(x)= 497.20595852183794
# differential_evolution step 330: f(x)= 497.20595852183794
# differential_evolution step 331: f(x)= 497.20595852183794
# differential_evolution step 332: f(x)= 497.20595852183794
# differential_evolution step 333: f(x)= 493.6718809083446
# differential_evolution step 334: f(x)= 493.6718809083446
# differential_evolution step 335: f(x)= 493.6718809083446
# differential_evolution step 336: f(x)= 493.6718809083446
# differential_evolution step 337: f(x)= 493.6718809083446
# differential_evolution step 338: f(x)= 493.6718809083446
# differential_evolution step 339: f(x)= 493.6718809083446
# differential_evolution step 340: f(x)= 493.6718809083446
# differential_evolution step 341: f(x)= 493.6718809083446
# differential_evolution step 342: f(x)= 493.6718809083446
# differential_evolution step 343: f(x)= 493.6718809083446
# differential_evolution step 344: f(x)= 493.6718809083446
# differential_evolution step 345: f(x)= 493.6718809083446
# differential_evolution step 346: f(x)= 493.6718809083446
# differential_evolution step 347: f(x)= 493.6718809083446
# differential_evolution step 348: f(x)= 493.6718809083446
# differential_evolution step 349: f(x)= 493.6718809083446
# differential_evolution step 350: f(x)= 493.6718809083446
# differential_evolution step 351: f(x)= 493.6718809083446
# differential_evolution step 352: f(x)= 493.6718809083446
# differential_evolution step 353: f(x)= 493.6718809083446
# differential_evolution step 354: f(x)= 493.6718809083446
# differential_evolution step 355: f(x)= 493.6718809083446
# differential_evolution step 356: f(x)= 493.6718809083446
# differential_evolution step 357: f(x)= 493.6718809083446
# differential_evolution step 358: f(x)= 493.6718809083446
# differential_evolution step 359: f(x)= 493.6718809083446
# differential_evolution step 360: f(x)= 493.6718809083446
# differential_evolution step 361: f(x)= 493.6718809083446
# differential_evolution step 362: f(x)= 493.6718809083446
# differential_evolution step 363: f(x)= 493.6718809083446
# differential_evolution step 364: f(x)= 493.6718809083446
# differential_evolution step 365: f(x)= 493.6718809083446
# differential_evolution step 366: f(x)= 491.5143234615805
# differential_evolution step 367: f(x)= 491.5143234615805
# differential_evolution step 368: f(x)= 491.5143234615805
# differential_evolution step 369: f(x)= 491.5143234615805
# differential_evolution step 370: f(x)= 491.4452813360566
# differential_evolution step 371: f(x)= 491.4452813360566
# differential_evolution step 372: f(x)= 491.4452813360566
# differential_evolution step 373: f(x)= 491.4452813360566
# differential_evolution step 374: f(x)= 491.4452813360566
# differential_evolution step 375: f(x)= 491.4452813360566
# differential_evolution step 376: f(x)= 491.4452813360566
# differential_evolution step 377: f(x)= 491.4452813360566
# differential_evolution step 378: f(x)= 491.4452813360566
# differential_evolution step 379: f(x)= 491.4452813360566
# differential_evolution step 380: f(x)= 491.4452813360566
# differential_evolution step 381: f(x)= 491.4452813360566
# differential_evolution step 382: f(x)= 491.32371484287114
# differential_evolution step 383: f(x)= 491.32371484287114
# differential_evolution step 384: f(x)= 491.32371484287114
# differential_evolution step 385: f(x)= 491.32371484287114
# differential_evolution step 386: f(x)= 491.32371484287114
# differential_evolution step 387: f(x)= 491.32371484287114
# differential_evolution step 388: f(x)= 491.32371484287114
# Polishing solution with 'L-BFGS-B'
# Best parameters found by Differential Evolution:
# [258.30636835 209.73633035 170.13808961 140.0090731  118.96714965
#  105.93202986  99.3675267   97.70617614  99.4595657  103.31758824
#  108.21002066 113.42250674 118.40525943 122.83717581 126.5169607
#  129.20040761 130.7080933  130.74315504 128.982533   125.00595026
#  118.44612665 108.9868563   96.56413234  81.40510981  64.20872483
#   46.16646564  28.94314666  14.44879295   4.48573185   0.
#    0.           0.           0.           0.           0.
#  427.21373913]
# Best cost found by Differential Evolution:
# -483.2580953688952

# %%
# prompt: convert all values in list result.x in integer and save the result in a variable called actions_de

actions_de = [int(x) for x in result_de.x]

len(actions_de)
# Out:
# 36

# %%
env=RetailerOrders()
env.run(actions_de)
# Out:
# 484.9287217792466

# %%
env.retailer_total_cost
# Out:
# 484.9287217792466
